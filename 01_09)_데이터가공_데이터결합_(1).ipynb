# %% [markdown]
# <a href="https://colab.research.google.com/github/memeanji/python-bootcamp/blob/main/01_09)_%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B0%80%EA%B3%B5_%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B2%B0%ED%95%A9_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **데이터 결합**
#
#
# ---

# %% [markdown]
# - 두 개의 데이터를 특정 컬럼을 기준으로 합칩니다.
# - 결합 방법에는 4가지가 있습니다.
# ![이미지](https://vitalflux.com/wp-content/uploads/2023/01/SQL-Joins-explained-using-Sets-640x451.png)
# - `pd.merge(데이터1, 데이터2, on=기준컬럼, how=결합방법)`

# %%
import pandas as pd

customer = pd.DataFrame({'id' : [i for i in range(1,7)],
                    'name' : ['민준','서연','서준','도현','지윤','채원'],
                    'age' : [15,30,40,20,23,31]})
customer
# Out:
#    id name  age
# 0   1   민준   15
# 1   2   서연   30
# 2   3   서준   40
# 3   4   도현   20
# 4   5   지윤   23
# 5   6   채원   31

# %%
orders = pd.DataFrame({'id' : [1,1,2,3,3,4,5,7,7,7],
                    'item' : ['사과','체리','바나나','사과','바나나','바나나','체리','사과','체리','바나나'],
                    'quantity' : [1, 2, 1, 1, 3, 2, 2, 3, 2, 1]})
orders
# Out:
#    id item  quantity
# 0   1   사과         1
# 1   1   체리         2
# 2   2  바나나         1
# 3   3   사과         1
# 4   3  바나나         3
# 5   4  바나나         2
# 6   5   체리         2
# 7   7   사과         3
# 8   7   체리         2
# 9   7  바나나         1

# %%
pd.merge(customer, orders, on='id', how='inner')
# id를 기준으로 innerjoin한거임
# 교집한만 가져오는 inner 조인
# Out:
#    id name  age item  quantity
# 0   1   민준   15   사과         1
# 1   1   민준   15   체리         2
# 2   2   서연   30  바나나         1
# 3   3   서준   40   사과         1
# 4   3   서준   40  바나나         3
# 5   4   도현   20  바나나         2
# 6   5   지윤   23   체리         2

# %%
pd.merge(customer, orders, on='id', how='left')
#왼쪽 기준으로 결합하고 없는 데이터는 null 값으로
# 왼쪽 혹은 오른쪽만을 가져오는 left/right 조인
# Out:
#    id name  age item  quantity
# 0   1   민준   15   사과       1.0
# 1   1   민준   15   체리       2.0
# 2   2   서연   30  바나나       1.0
# 3   3   서준   40   사과       1.0
# 4   3   서준   40  바나나       3.0
# 5   4   도현   20  바나나       2.0
# 6   5   지윤   23   체리       2.0
# 7   6   채원   31  NaN       NaN

# %%
pd.merge(customer, orders, on='id', how='right')
#오른쪽 기준으로 하고 왼쪽에 없는 값들은 null 값으로
# Out:
#    id name   age item  quantity
# 0   1   민준  15.0   사과         1
# 1   1   민준  15.0   체리         2
# 2   2   서연  30.0  바나나         1
# 3   3   서준  40.0   사과         1
# 4   3   서준  40.0  바나나         3
# 5   4   도현  20.0  바나나         2
# 6   5   지윤  23.0   체리         2
# 7   7  NaN   NaN   사과         3
# 8   7  NaN   NaN   체리         2
# 9   7  NaN   NaN  바나나         1

# %%
pd.merge(orders, customer, on='id', how='left')
# Out:
#    id item  quantity name   age
# 0   1   사과         1   민준  15.0
# 1   1   체리         2   민준  15.0
# 2   2  바나나         1   서연  30.0
# 3   3   사과         1   서준  40.0
# 4   3  바나나         3   서준  40.0
# 5   4  바나나         2   도현  20.0
# 6   5   체리         2   지윤  23.0
# 7   7   사과         3  NaN   NaN
# 8   7   체리         2  NaN   NaN
# 9   7  바나나         1  NaN   NaN

# %%
pd.merge(customer, orders, on='id', how='outer')
# Out:
#     id name   age item  quantity
# 0    1   민준  15.0   사과       1.0
# 1    1   민준  15.0   체리       2.0
# 2    2   서연  30.0  바나나       1.0
# 3    3   서준  40.0   사과       1.0
# 4    3   서준  40.0  바나나       3.0
# 5    4   도현  20.0  바나나       2.0
# 6    5   지윤  23.0   체리       2.0
# 7    6   채원  31.0  NaN       NaN
# 8    7  NaN   NaN   사과       3.0
# 9    7  NaN   NaN   체리       2.0
# 10   7  NaN   NaN  바나나       1.0

# %% [markdown]
# - 두 데이터의 기준 컬럼명이 다를 경우에는
#     - `pd.merge(데이터1, 데이터2, left_on=데이터1의 기준컬럼, right_on=데이터2의 기준컬럼, how=결합방법)`

# %%
orders = orders.rename({'id':'customer_id'}, axis=1)

# %%
pd.merge(customer, orders, left_on='id', right_on='customer_id', how='inner')

# customer는 id 기준으로 orders는 customer_id 기준으로 이너 조인해달라는 말임
# Out:
#    id name  age  customer_id item  quantity
# 0   1   민준   15            1   사과         1
# 1   1   민준   15            1   체리         2
# 2   2   서연   30            2  바나나         1
# 3   3   서준   40            3   사과         1
# 4   3   서준   40            3  바나나         3
# 5   4   도현   20            4  바나나         2
# 6   5   지윤   23            5   체리         2
