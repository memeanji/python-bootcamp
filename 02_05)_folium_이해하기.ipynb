# %% [markdown]
# <a href="https://colab.research.google.com/github/memeanji/python-bootcamp/blob/main/02_05)_folium_%EC%9D%B4%ED%95%B4%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **folium 이해하기**
#
#
# ---

# %%
import folium

# %% [markdown]
# ## **[1] 특정 장소의 지도 시각화하기**
# - 네이버 지도에서 원하는 위치를 검색하고 공유 버튼을 통해 URL을 복사하세요.
# - [링크](https://xn--yq5bk9r.com/blog/map-coordinates)에 복사한 url을 붙여넣고 위도와 경도를 확인하세요.
#
#
# ```
# f = folium.Figure(width=가로길이, height=세로길이)
# m = folium.Map(location=[위도, 경도], zoom_start=줌할정도).add_to(f)
# m.save('test.html') #지도 저장
# m
# ```

# %%
f = folium.Figure(width=700, height=500) # 지도크기를 말하는거임
m = folium.Map(location=[37.510781008592716, 127.09607026177875], zoom_start=16).add_to(f)
m
#m = 위도, 경도임 , 줌을 얼마나 크게 할건지에 대한거임
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2349f8160bf6de3ab61ba94784364679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2349f8160bf6de3ab61ba94784364679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2349f8160bf6de3ab61ba94784364679 = L.map(
#                 &quot;map_2349f8160bf6de3ab61ba94784364679&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ba4e276a50bb3b090cb9264ef9825c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
m.save('test.html') #저장하고 시프면 html로 저장하면 됨

# %% [markdown]
# ## **[2] 마커 추가하기**
#
#
# ```
# #장소 표시 마커
# folium.Marker([위도, 경도]
#                 , tooltip=마우스 오버시 나타남
#                 , popup=클릭시 나타남
#                 , icon=folium.Icon(color=색, icon=모양)).add_to(지도)
#
# #원 형태 마커
# folium.CircleMarker([위도, 경도]
#                 , radius=범위
#                 , color=색).add_to(지도)
# ```

# %%
folium.Marker([37.510781008592716, 127.09607026177875]
              , tooltip='롯데월드').add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2349f8160bf6de3ab61ba94784364679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2349f8160bf6de3ab61ba94784364679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2349f8160bf6de3ab61ba94784364679 = L.map(
#                 &quot;map_2349f8160bf6de3ab61ba94784364679&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ba4e276a50bb3b090cb9264ef9825c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var marker_e0f881f5485e7f3b82290293fbd039d4 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             marker_e0f881f5485e7f3b82290293fbd039d4.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
folium.Marker([37.510781008592716, 127.09607026177875]
              , tooltip='롯데월드'
              , icon = folium.Icon(color='red', icon='heart')).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2349f8160bf6de3ab61ba94784364679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2349f8160bf6de3ab61ba94784364679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2349f8160bf6de3ab61ba94784364679 = L.map(
#                 &quot;map_2349f8160bf6de3ab61ba94784364679&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_
L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var icon_08e7e84b638f14e3e4b81f66fc1bce16 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_abc87c43adb105ee214c49483b680bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50af98cc630e8b67bcbb894bfe261739 = $(`&lt;div id=&quot;html_50af98cc630e8b67bcbb894bfe261739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe src=&quot;https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Lotte_World_Theme_Park.jpg/440px-Lotte_World_Theme_Park.jpg&quot;&gt;&lt;/iframe&gt;&lt;/div

# %%
folium.CircleMarker([37.510781008592716, 127.09607026177875]
              , color = 'hotpink'
              , radius = 50).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2349f8160bf6de3ab61ba94784364679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2349f8160bf6de3ab61ba94784364679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2349f8160bf6de3ab61ba94784364679 = L.map(
#                 &quot;map_2349f8160bf6de3ab61ba94784364679&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81ba4e276a50bb3b090cb9264ef9825c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var marker_e0f881f5485e7f3b82290293fbd039d4 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             marker_e0f881f5485e7f3b82290293fbd039d4.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var marker_0d0fd0660eb9f7fc3a56a736791a5e38 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var icon_64f9fe1d418898eba9c8a764c25d868e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;coffee&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_0d0fd0660eb9f7fc3a56a736791a5e38.bindTooltip(
#                 `&lt;div&gt;
#                      카페 마나랑
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0d0fd0660eb9f7fc3a56a736791a5e38.setIcon(icon_64f9fe1d418898eba9c8a764c25d868e);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#                 marker_0d0fd0660eb9f7fc3a56a736791a5e38.setIcon(icon_64f9fe1d418898eba9c8a764c25d868e);
#
#
#             var marker_2d8845f38347e42f09cab6a46eb30ad2 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var icon_56fc74216b3ce3d8a4052f9799b7d699 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_2d8845f38347e42f09cab6a46eb30ad2.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2d8845f38347e42f09cab6a46eb30ad2.setIcon(icon_56fc74216b3ce3d8a4052f9799b7d699);
#
#
#             tile_layer_81ba4e276a50bb3b090cb9264ef9825c.addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#                 marker_0d0fd0660eb9f7fc3a56a736791a5e38.setIcon(icon_64f9fe1d418898eba9c8a764c25d868e);
#
#
#                 marker_2d8845f38347e42f09cab6a46eb30ad2.setIcon(icon_56fc74216b3ce3d8a4052f9799b7d699);
#
#
#             var marker_d7590d10bd8a41f0debf21b5b6a0506c = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {
# }
#             ).addTo(map_2349f8160bf6de3ab61ba94784364679);
#
#
#             var icon_08e7e84b638f14e3e4b81f66fc1bce16 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_abc87c43adb105ee214c49483b680bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50af98cc630e8b67bcbb894bfe261739 = $(`&lt;div id=&quot;html_50af98cc630e8b67bcbb894bfe261739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe src=&quot;https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Lotte_World_Theme_Park.jpg/440px-Lotte_World_Theme_Park.jpg&quot;&gt;&lt;/iframe&gt;&lt;/div
