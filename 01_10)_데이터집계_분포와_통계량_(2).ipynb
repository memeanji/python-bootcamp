# %% [markdown]
# <a href="https://colab.research.google.com/github/memeanji/python-bootcamp/blob/main/01_10)_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A7%91%EA%B3%84_%EB%B6%84%ED%8F%AC%EC%99%80_%ED%86%B5%EA%B3%84%EB%9F%89_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **분포와 통계량**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/data/titanic_train.csv'
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## **분포 및 요약 통계**
# - `describe()`: 컬럼별 값의 갯수, 평균, 표준편차, 최솟값, 최댓값, 사분위수를 보여줍니다.

# %%
df.describe()
#describe를 쓰면 숫자형으로 된 컬럼들을 개수,평균,표준편차,최소/최대,사분위수를 볼 수 있음
#Fare를 보면  최소가 0이고 최대가 512인데 중앙값이 14고 3사분위가 31이니까
#왼쪽으로 치우쳐있겠구나정도 파악할 수 있음
#데이터를 파악할때 가장 많이 사용하는 함수 중 하나임
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## **대푯값**
# |메소드|설명|
# |:--|:--|
# |min()|최솟값|
# |max()|최댓값|
# |mean()|평균|
# |median()|중간값|
# |std()|표준편차|
# |var()|분산|
# |quantile()|분위수|

# %%
df.min() # 숫자와 문자가 섞여있어서 오류남
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c3612c624a3f> in <cell line: 0>()
# ----> 1 df.min()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in min(self, axis, skipna, numeric_only, **kwargs)
#   11641         **kwargs,
#   11642     ):
# > 11643         result = super().min(axis, skipna, numeric_only, **kwargs)
#   11644         if isinstance(result, Series):
#   11645             result = result.__finalize__(self, method="min")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in min(self, axis, skipna, numeric_only, **kwargs)
#   12386         **kwargs,
#   12387     ):
# > 12388         return self._stat_function(
#   12389             "min",
#   12390             nanops.nanmin,
#
# ...

# %%
df.min(numeric_only=True)
#(numeric_only=True 옵션을 주면 숫자형 열만 골라서 최소값을 계산해
#즉 숫자형들만 가지고 계산해줌
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %%
df.quantile(0.2, numeric_only=True)
# Out:
# PassengerId    179.0000
# Survived         0.0000
# Pclass           1.0000
# Age             19.0000
# SibSp            0.0000
# Parch            0.0000
# Fare             7.8542
# Name: 0.2, dtype: float64

# %%
df.quantile(0.9, numeric_only=True)
# Out:
# PassengerId    802.0000
# Survived         1.0000
# Pclass           3.0000
# Age             50.0000
# SibSp            1.0000
# Parch            2.0000
# Fare            77.9583
# Name: 0.9, dtype: float64

# %% [markdown]
# ## **변수의 상관관계 확인하기**
# - 상관관계 분석은 두 변수의 관련성을 구하는 분석입니다.
# - 두 변수 간의 연관된 정도이지 인과관계를 설명하지 않습니다.
# - 상관계수 = 두 변수가 함께 변하는 정도 / 두 변수가 각각 변하는 정도
# ![이미지](https://cdn.imweb.me/upload/S202101041a4e45576971e/a29a57bd847b1.png)
# - `.corr()`

# %%
df.corr(numeric_only=True)
#대각선은 자기자신과의 상관관계니까 1로 나오는거임
# 운임이 높을수록 생존률이 높았네
# 이정도 파악가능
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
# pclass와 fare가 음의상관관계가 높고
# fare 와 age도 음의상관관계가 높고
# pclass와 fare도 음의 상관관계가 높다는걸 볼 수 있음
# 시각화파트에서 자세히하고 여기선 이정도만
